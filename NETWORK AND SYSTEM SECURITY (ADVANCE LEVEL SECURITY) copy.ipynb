# %%
# Write your script here
import random
import secrets
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from Crypto.Util.Padding import pad, unpad
from base64 import b64encode, b64decode
from Crypto.PublicKey import RSA
from Crypto.Cipher import PKCS1_OAEP
from Crypto.Random import get_random_bytes
from cryptography.hazmat.primitives.ciphers import Cipher, algorithms, modes
from cryptography.hazmat.backends import default_backend
from cryptography.hazmat.primitives import cmac
from cryptography.hazmat.primitives import hmac, hashes
from cryptography.hazmat.backends import default_backend
from cryptography.hazmat.primitives.asymmetric import padding,rsa
from cryptography.hazmat.primitives.asymmetric import ec
from cryptography.hazmat.primitives import hashes, serialization
from cryptography.hazmat.primitives.asymmetric import ec, utils
from cryptography.exceptions import InvalidSignature
from Crypto.Signature import pkcs1_15
from cryptography.hazmat.primitives.ciphers import Cipher, algorithms, modes
from Crypto.Hash import SHA3_256
from Crypto.Signature import pkcs1_15
from Crypto.PublicKey import RSA
import hashlib
import rsa

class ExecuteCrypto(object): # Do not change this
    def generate_keys(self):
        """Generate keys"""
        
        public_key_sender_rsa, private_key_sender_rsa=rsa.newkeys(2048)
        public_key_receiver_rsa, private_key_receiver_rsa=rsa.newkeys(2048)       
        private_key = ec.generate_private_key(
            ec.SECP256R1(),  # Use the NIST P-256 curve (secp256r1)
             default_backend()
             )
        public_key = private_key.public_key()
        public_key_sender_ecc=public_key
        private_key_sender_ecc=private_key
        symmetric_key=secrets.token_bytes(16)
        print("Symmetric Key") # Do not change this
        print(symmetric_key) # Do not change this
        print("Sender's RSA Public Key") # Do not change this
        print(public_key_sender_rsa) # Do not change this
        print("Sender's RSA Private Key") # Do not change this
        print(private_key_sender_rsa) # Do not change this
        print("Receiver's RSA Public Key") # Do not change this
        print(public_key_receiver_rsa) # Do not change this
        print("Receiver's RSA Private Key") # Do not change this
        print(private_key_receiver_rsa) # Do not change this
        print("Sender's ECC Public Key") # Do not change this
        print(public_key_sender_ecc) # Do not change this
        print("Sender's ECC Private Key") # Do not change this
        print(private_key_sender_ecc) # Do not change this

        return (symmetric_key,public_key_sender_rsa, 
        private_key_sender_rsa,public_key_receiver_rsa, 
        private_key_receiver_rsa,public_key_sender_ecc, private_key_sender_ecc) # Do not change this

    def generate_nonces(self):
        """Generate nonces"""

        # Write your script here
        nonce_aes_cbc=get_random_bytes(16)
        nonce_aes_ctr=get_random_bytes(8)
        nonce_encrypt_rsa=get_random_bytes(256)
        nonce_aes_cmac=get_random_bytes(16)
        nonce_hmac=get_random_bytes(32)
        nonce_tag_rsa=get_random_bytes(32)
        nonce_ecdsa=get_random_bytes(32)
        nonce_aes_gcm=get_random_bytes(8)
       


        print("Nonce for AES-128-CBC") # Do not change this
        print(nonce_aes_cbc) # Do not change this
        print("Nonce for AES-128-CTR") # Do not change this
        print(nonce_aes_ctr) # Do not change this
        print("NOnce for RSA-2048") # Do not change this
        print(nonce_encrypt_rsa) # Do not change this
        print("Nonce for AES-128-CMAC") # Do not change this
        print(nonce_aes_cmac) # Do not change this
        print("Nonce for SHA3-256-HMAC") # Do not change this
        print(nonce_hmac) # Do not change this
        print("Nonce for RSA-2048-SHA3-256") # Do not change this
        print(nonce_tag_rsa) # Do not change this
        print("Nonce for ECDSA") # Do not change this
        print(nonce_ecdsa) # Do not change this
        print("Nonce for AES-128-GCM") # Do not change this
        print(nonce_aes_gcm) # Do not change this

        return nonce_aes_cbc, nonce_aes_ctr, nonce_encrypt_rsa, nonce_aes_cmac, \
                nonce_hmac, nonce_tag_rsa, nonce_ecdsa, nonce_aes_gcm # Do not change this

    def encrypt(self, algo, key, plaintext, nonce): # Do not change this
        """Encrypt the given plaintext"""
        
        # Write your script here
        if algo == 'AES-128-CBC-ENC': # Do not change this
            # Write your script here
            cipher = AES.new(key, AES.MODE_CBC,nonce)
            ciphertext = cipher.encrypt(pad(plaintext.encode('utf-8'), AES.block_size))

        elif algo == 'AES-128-CTR-ENC': # Do not change this
            # Write your script here
            cipher = AES.new(key, AES.MODE_CTR, nonce=nonce)
            ciphertext = cipher.encrypt(plaintext.encode('utf-8'))

        elif algo == 'RSA-2048-ENC': # Do not change this
            # Write your script here
            ciphertext = rsa.encrypt(plaintext,key)

        else: # Do not change this
            raise Exception("Unexpected algorithm") # Do not change this

        # Write your script here


        print("Algorithm") # Do not change this
        print(algo) # Do not change this
        print("Encryption Key") # Do not change this
        print(key) # Do not change this
        print("Plaintext") # Do not change this
        print(plaintext) # Do not change this
        print("Nonce") # Do not change this
        print(nonce) # Do not change this
        print("Ciphertext") # Do not change this
        print(ciphertext) # Do not change this

        return ciphertext # Do not change this

    def decrypt(self, algo, key, ciphertext, nonce): # Do not change this
        """Decrypt the given ciphertext"""
        # Write your script here

        if algo=='AES-128-CBC-DEC': # Do not change this
            # Write your script here
            cipher = AES.new(key, AES.MODE_CBC, nonce)
            decrypted = unpad(cipher.decrypt(ciphertext), AES.block_size)
            plaintext=decrypted.decode('utf-8')

        elif algo == 'AES-128-CTR-DEC': # Do not change this
            # Write your script here
            cipher = AES.new(key, AES.MODE_CTR, nonce=nonce)
            decrypted = cipher.decrypt(ciphertext)
            plaintext=decrypted.decode('utf-8')

        elif algo == 'RSA-2048-DEC': # Do not change this
            # Write your script here
            plaintext=rsa.decrypt(ciphertext,key)

        else: # Do not change this
            raise Exception("Unexpected algorithm") # Do not change this

        # Write your script here

        print("Algorithm") # Do not change this
        print(algo) # Do not change this
        print("Decryption Key") # Do not change this
        print(key) # Do not change this
        print("Plaintext") # Do not change this
        print(plaintext) # Do not change this
        print("Nonce") # Do not change this
        print(nonce) # Do not change this
        print("Ciphertext") # Do not change this
        print(ciphertext) # Do not change this
        return plaintext # Do not change this

    def generate_auth_tag(self, algo, key, plaintext, nonce): # Do not change this
        """Generate the authenticate tag for the given plaintext"""

        # Write your script here

        if algo =='AES-128-CMAC-GEN': # Do not change this
            # Write your script here
            backend = default_backend()   
            aes_cmac = cmac.CMAC(algorithms.AES(key), backend)
            aes_cmac.update(plaintext.encode('utf-8'))
            auth_tag = aes_cmac.finalize()

        elif algo =='SHA3-256-HMAC-GEN': # Do not change this
            # Write your script here
             h = hmac.HMAC(key, hashes.SHA3_256(), backend=default_backend())

 
             h.update(plaintext.encode('utf-8'))

             # Finalize the HMAC computation and get the digest
             auth_tag  = h.finalize()
         

        elif algo =='RSA-2048-SHA3-256-SIG-GEN': # Do not change this
            # Write your script here
            hash1 = SHA3_256.new()

            # Update hash object with plaintext data
            hash1.update(plaintext.encode('utf-8'))

            # Obtain the hash value
            hash_value = hash1.digest()

            # Sign the hashed message
            auth_tag = rsa.sign(hash_value, key, 'SHA-256')


        elif algo =='ECDSA-256-SHA3-256-SIG-GEN': # Do not change this
            # Write your script here
            
            auth_tag = key.sign(
            plaintext.encode('utf-8'),
               ec.ECDSA(hashes.SHA3_256())
                   )
     

        else:
            raise Exception("Unexpected algorithm") # Do not change this

        # Write your script here


        print("Algorithm") # Do not change this
        print(algo) # Do not change this
        print("Authentication Key") # Do not change this
        print(key) # Do not change this
        print("Plaintext") # Do not change this
        print(plaintext) # Do not change this
        print("Nonce") # Do not change this
        print(nonce) # Do not change this
        print("Authentication Tag") # Do not change this
        print(auth_tag) # Do not change this

        return auth_tag # Do not change this

    def verify_auth_tag(self, algo, key, plaintext, nonce, auth_tag): # Do not change this
        """Verify the authenticate tag for the given plaintext"""
    
        # Write your script here
        auth_tag_valid=False

        if algo =='AES-128-CMAC-VRF': # Do not change this
            # Write your script here
            auth_tag_valid=False
            backend = default_backend()   
            aes_cmac = cmac.CMAC(algorithms.AES(key), backend)
            aes_cmac.update(plaintext.encode('utf-8'))
            tag = aes_cmac.finalize()
            if(auth_tag==tag):
                auth_tag_valid=True

        elif algo =='SHA3-256-HMAC-VRF': # Do not change this
            # Write your script here
            auth_tag_valid=False
            h = hmac.HMAC(key, hashes.SHA3_256(), backend=default_backend())

 
            h.update(plaintext.encode('utf-8'))

             # Finalize the HMAC computation and get the digest
            tag  = h.finalize()
            if(auth_tag == tag):
                auth_tag_valid=True
                

        elif algo =='RSA-2048-SHA3-256-SIG-VRF': # Do not change this
            # Write your script here
            auth = SHA3_256.new()

            # Update hash object with plaintext data
            auth.update(plaintext.encode('utf-8'))

            # Obtain the hash value
            hash_value = auth.digest()

            # Verify the signature
            auth_tag_valid = False
            if rsa.verify(hash_value, auth_tag, key):
                auth_tag_valid = True

        elif algo =='ECDSA-256-SHA3-256-SIG-VRF': # Do not change this
            # Write your script here
            auth_tag_valid=False
            try:
                key.verify(
            auth_tag,
            plaintext.encode('utf-8'),
            ec.ECDSA(hashes.SHA3_256())
             )
                auth_tag_valid = True
            except InvalidSignature:
                auth_tag_valid = False

                

        else:
            raise Exception("Unexpected algorithm") # Do not change this

        # Write your script here

        print("Algorithm") # Do not change this
        print(algo) # Do not change this
        print("Authentication Key") # Do not change this
        print(key) # Do not change this
        print("Plaintext") # Do not change this
        print(plaintext) # Do not change this
        print("Nonce") # Do not change this
        print(nonce) # Do not change this
        print("Authentication Tag") # Do not change this
        print(auth_tag) # Do not change this
        print("Authentication Tag Valid") # Do not change this
        print(auth_tag_valid) # Do not change this

        return auth_tag_valid # Do not change this

    def encrypt_generate_auth(self, algo, key_encrypt, key_generate_auth, plaintext, nonce): # Do not change this
        """Encrypt and generate the authentication tag for the given plaintext"""

        # Write your script here

        if algo == 'AES-128-GCM-GEN': # Do not change this
            # Write your script here
            # Write your script here

            cipher = Cipher(algorithms.AES(key_encrypt), modes.GCM(nonce), backend=default_backend())
            encryptor = cipher.encryptor()

            # Encrypt the plaintext and obtain the ciphertext
            ciphertext = encryptor.update(plaintext.encode('utf-8')) + encryptor.finalize()

            # Obtain the authentication tag
            auth_tag = encryptor.tag

        else:
            raise Exception("Unexpected algorithm") # Do not change this

        # Write your script here

        print("Algorithm") # Do not change this
        print(algo) # Do not change this
        print("Encryption Key") # Do not change this
        print(key_encrypt) # Do not change this
        print("Authentication Key") # Do not change this
        print(key_generate_auth) # Do not change this
        print("Plaintext") # Do not change this
        print(plaintext) # Do not change this
        print("Nonce") # Do not change this
        print(nonce) # Do not change this
        print("Ciphertext") # Do not change this
        print(ciphertext) # Do not change this
        print("Authentication Tag") # Do not change this
        print(auth_tag) # Do not change this

        return ciphertext, auth_tag # Do not change this

    def decrypt_verify_auth(self, algo, key_decrypt, key_verify_auth, ciphertext, nonce, auth_tag): # Do not change this
        """Decrypt and verify the authentication tag for the given plaintext"""

        

        if algo == 'AES-128-GCM-VRF': # Do not change this
            # Write your script here
            aes = AES.new(key_decrypt, AES.MODE_GCM, nonce=nonce)
            plaintext = aes.decrypt(ciphertext).decode('utf-8')
            try:
                aes.verify(auth_tag)
                auth_tag_valid = True
            except ValueError:
                auth_tag_valid = False
    

        else:
            raise Exception("Unexpected algorithm") # Do not change this

        # Write your script here

        print("Algorithm") # Do not change this
        print(algo) # Do not change this
        print("Decryption Key") # Do not change this
        print(key_decrypt) # Do not change this
        print("Authentication Key") # Do not change this
        print(key_verify_auth) # Do not change this
        print("Plaintext") # Do not change this
        print(plaintext) # Do not change this
        print("Nonce") # Do not change this
        print(nonce) # Do not change this
        print("Ciphertext") # Do not change this
        print(ciphertext) # Do not change this
        print("Authentication Tag") # Do not change this
        print(auth_tag) # Do not change this
        print("Authentication Tag Valid") # Do not change this
        print(auth_tag_valid) # Do not change this

        return plaintext, auth_tag_valid # Do not change this

if __name__ == '__main__': # Do not change this
    ExecuteCrypto() # Do not change this

# %%
import time

# %%
test=ExecuteCrypto()
start=time.time()
s=test.generate_keys()
end=time.time()
print("time taken is ",start-end)
len(str(s[0]))
# Out:
# Symmetric Key
# b'\x8dEe\xfb\x98tMK\x827@{\x92D\x01\x98'
# Sender's RSA Public Key
# PublicKey(..., 65537)
# Sender's RSA Private Key
# PrivateKey(..., 65537, ..., , )
# Receiver's RSA Public Key
# PublicKey(..., 65537)
# Receiver's RSA Private Key
# PrivateKey(..., 65537, ..., , )
# Sender's ECC Public Key
# <cryptography.hazmat.backends.openssl.ec._EllipticCurvePublicKey object at 0x7f850269e790>
# Sender's ECC Private Key
# <cryptography.hazmat.backends.openssl.ec._EllipticCurvePrivateKey object at 0x7f850253ddc0>
# time taken is  -10.25118899345398
# 40

# %%
n=test.generate_nonces()
# Out:
# Nonce for AES-128-CBC
# b'\xf6bD\x1e\xa4\x1169\x94\x06\x82j#P\xd0\x0f'
# Nonce for AES-128-CTR
# b'\xf2v\x89\xb5\xb1X\x9d\x03'
# NOnce for RSA-2048
# b'\xf1\xf2<\xfa\xed\x0e>~\x93,\x89bs\xa4\xcf\x96Lo\xb4\xcf\x06\xf0Z\xfa\xfa\xe4\x9d\xd8]KS\xef\x1d\xf5/\x82o\xa0i\xa4|\xf77\xcb\xa9\xbc\xfaR\xeb\x9c\xde\xaa\x0c\x15h\xafX%\xd0_\xeb\xe2\xc41\xcfa\x1c\xfb*\xc1/jd4\xcf\x81\xf7\xdbu\xb7|\xd0\xf4\x89WO\xb1Z\xf9\xc5\xbcz\x15 {\x97\xa8#9\x7f\xd7L\xec\xd9\xef\x01\x8f<\\\xf0\xe8\x084\x928\xcdL\x94Gk\x91|\xc2]\x1b/]\xf3\x05r#\x94K\xe7K\xdb\xb1\xf5\xf4t)_\x95@\x8c\x88\x88X\x89\xdf5v+\xe3\xa4\xa5\xae+2\xe1\xcb\x96\xeb\xaeHn\xfd\r\x7f\xb2\x96y\xe0\x9c0\x0ch\xc9\x8aj\xde\xa5\x08F%\xce#O\xc8\xd5 d\xd3\x9e\xe1\xfcF\xbc\x9d\x04*w\xc0\xb7\xda\xdb\xfe/\xf4\x90\x95\xfb\xeb\xe2\x1b\xbd\xe4\xb5\xeb\xbb\xd5\xdbg\x10\xda\x8b\xe8\xc4\x9d\xe8\xd4\xc2\xce])\x97\xdf\xb3\xf3\t\xba\x10\xc3\x9d\xf8\xa4F\xc0fM\xc3\x0b\x8e\xe0\xecq'
# Nonce for AES-128-CMAC
# b'\xd2\x91\x8b\x191z\xd2\x0c\x9f\x11\xd5\xef5\xf5%>'
# Nonce for SHA3-256-HMAC
# b'\x85\x80\x02\x83N\xfa\xb4`FvF7\xb9\xb2\x18\x94\xbb}\xa8L\x9d=\x85v\x9f\x0b^\x8d\xe4\xb9Q\xbf'
# Nonce for RSA-2048-SHA3-256
# b'\x10\xe1\n\xbd2\x07\x10o\xa7\x94\xd4\xd8\xa6\xfb\x81wJ\xd2\xfeyI\x95\xf0\xec\xb4^\x8f+\xbd5\x04\xc9'
# Nonce for ECDSA
# b'\xdad\xdd\xbc\xa8\x9a\x86\xeeU\xd5\xaaH\x8bg\x9e-\xe0.\x12\xfcv\xfe\xae\xc1O\xef\x0e;}\xc8U\xb4'
# Nonce for AES-128-GCM
# b'<7(\xc1aG\xbe\x9a'

# %%
##data length == 114
##key length == 40
start=time.time()
plaintext="Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration."
test.encrypt('AES-128-CBC-ENC',s[0],plaintext,n[0])
end=time.time()
print(len(plaintext))
print(len(str(s[0])))
print(end-start)
# Out:
# Algorithm
# AES-128-CBC-ENC
# Encryption Key
# b'\x8dEe\xfb\x98tMK\x827@{\x92D\x01\x98'
# Plaintext
# Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.
# Nonce
# b'\xf6bD\x1e\xa4\x1169\x94\x06\x82j#P\xd0\x0f'
# Ciphertext
# b"\x83\x19?\xee?,\xd8\xe7\xe8|\x8el\xcdy\x19oE\xa6\x010\xf7\x1f\xee\x07\x1e\xf1T\x96\x1b\xe8\x8c\x99\x82\xf9\xf7\x05\xbd\xf8)\x85\x00h/da\x1a\xf4`N\xa9$\xc3\x11V?\x05;\xa1\x04$<\x83\x04\xef\xaeU\x82^Z,\xa0\xfd\xba\xeb\x8b^\xbb\xa1\x06\x01\xdc\x1f!@\x05\xb7Zt\xe6w|0?\xf7\xba'\xfd}G\xab\x8dcM\x12\x97\xce\xdd\xf8\xf4\xc1\xa3\xbb\xa1\x03\x12]\x12%i\x1f\x1c\xf9\x90\x88r{\xbeu"
# 114
# 40
# 0.0031747817993164062

# %%
start=time.time()
plaintext="Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration."
test.encrypt('AES-128-CTR-ENC',s[0],plaintext,n[1])
end=time.time()
print(len(plaintext))
print(len(str(s[0])))
print(end-start)
# Out:
# Algorithm
# AES-128-CTR-ENC
# Encryption Key
# b'\x8dEe\xfb\x98tMK\x827@{\x92D\x01\x98'
# Plaintext
# Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.
# Nonce
# b'\xf2v\x89\xb5\xb1X\x9d\x03'
# Ciphertext
# b"\xbd\xc7\x9e\xac\xff\xed\xe7\x82\xf7\x11\xd9\xc3\xdfM\xa37\xd0\xc6\x00\xafG@\xd6\xb07\xda\x15\x95\xb3E\x8a6KD\x9d\xb60\xe3\x0cf\xb6 \xe0\x0f]\xc5>\xe1\xe4\xd4\x8a\xe6\x05x,SW\xeb\xcb\x17\xd5\xe5\xc1|)X\xbf\xcb\xc5;%\xac\xd7!>\x17=]J\x84\xb9o\xe9\xa4\xb94x\x83\xc5N\xa7\xb8\x85\x0e\xd4\x91\xf6'\xb4\xcf@\xae\xa3\xfc\x06\\\xb1v#\xc7\r\xfaJ\x0e"
# 114
# 40
# 0.004636049270629883

# %%
##data length == 114
##key length == 2048 bits
start=time.time()
plaintext="Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration."
test.encrypt('RSA-2048-ENC',s[3],bytes(plaintext.encode('utf-8')),n[2])
end=time.time()
print(len(plaintext))
print(end-start)
# Out:
# Algorithm
# RSA-2048-ENC
# Encryption Key
# PublicKey(..., 65537)
# Plaintext
# b'Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.'
# Nonce
# b'\xf1\xf2<\xfa\xed\x0e>~\x93,\x89bs\xa4\xcf\x96Lo\xb4\xcf\x06\xf0Z\xfa\xfa\xe4\x9d\xd8]KS\xef\x1d\xf5/\x82o\xa0i\xa4|\xf77\xcb\xa9\xbc\xfaR\xeb\x9c\xde\xaa\x0c\x15h\xafX%\xd0_\xeb\xe2\xc41\xcfa\x1c\xfb*\xc1/jd4\xcf\x81\xf7\xdbu\xb7|\xd0\xf4\x89WO\xb1Z\xf9\xc5\xbcz\x15 {\x97\xa8#9\x7f\xd7L\xec\xd9\xef\x01\x8f<\\\xf0\xe8\x084\x928\xcdL\x94Gk\x91|\xc2]\x1b/]\xf3\x05r#\x94K\xe7K\xdb\xb1\xf5\xf4t)_\x95@\x8c\x88\x88X\x89\xdf5v+\xe3\xa4\xa5\xae+2\xe1\xcb\x96\xeb\xaeHn\xfd\r\x7f\xb2\x96y\xe0\x9c0\x0ch\xc9\x8aj\xde\xa5\x08F%\xce#O\xc8\xd5 d\xd3\x9e\xe1\xfcF\xbc\x9d\x04*w\xc0\xb7\xda\xdb\xfe/\xf4\x90\x95\xfb\xeb\xe2\x1b\xbd\xe4\xb5\xeb\xbb\xd5\xdbg\x10\xda\x8b\xe8\xc4\x9d\xe8\xd4\xc2\xce])\x97\xdf\xb3\xf3\t\xba\x10\xc3\x9d\xf8\xa4F\xc0fM\xc3\x0b\x8e\xe0\xecq'
# Ciphertext
# b's\x18F\xfa\xf0kb\xd8\xd2\x1c\x0b\x0e\xebY\x00x\xa1\xe7T\r\x93\xe3\xdc1\xcapnj\xae\xe1,\xfaR\x01H\xa6u\x1b-\x85y \x05B\xef\xfbm/\xc7Y\xa9\xb0\xa1^\x17\x18\xb7I\xf8\\\xca]\x88\xff\xfb\xe4\xea\x96\xc5\xf9\xa2?a\xd3\x0ePui\x08Z\xf3\x02\xe3\xb7\x19M\xa7K\x15\xe6\xf2*R5\xc4\xde\xa7@N0\xaa\xb8]~\xda#O\x02\xb5a\xf7\xd5"\xebQ~\'\xfaI\xd2\x9b\xa7\xce\xf4X\x1act\xb1E\xc1H|\xe0\xda\x81s\xe5\x9a\xe1\xdeJR\xb3\xd0D\xad\x1a\x03\x11Lu\x8f\xd2\xe1\xcb\xb8\xcc\x89\xae\xee\xcb \xdcc\xb6\xa3\xf4\xd5c\xb1\x81\xb3X\x95\xac%\xa1\xa5c\x97\xbb\x0c\xaa\xe7\xd0K,?\x1et\xec\xfb&\xee\xb4\'\xdd,\xdc\xd0\x96\x0e\xce\xcat\x95\xd8\xd5j@y\x01aO\xd4a\x85R{\xa2P\xa5\xb9z\x00\x1a\x15\xd2~h\x0c"ojBiG\xff4\xa96\x9a7\x16\xcc\x97\xc9 u\xc1`\\[\x01\x95'
# 114
# 0.0013587474822998047

# %%
##data length == 114
##key length == 40
start=time.time()
ciphertext=b"\x83\x19?\xee?,\xd8\xe7\xe8|\x8el\xcdy\x19oE\xa6\x010\xf7\x1f\xee\x07\x1e\xf1T\x96\x1b\xe8\x8c\x99\x82\xf9\xf7\x05\xbd\xf8)\x85\x00h/da\x1a\xf4`N\xa9$\xc3\x11V?\x05;\xa1\x04$<\x83\x04\xef\xaeU\x82^Z,\xa0\xfd\xba\xeb\x8b^\xbb\xa1\x06\x01\xdc\x1f!@\x05\xb7Zt\xe6w|0?\xf7\xba'\xfd}G\xab\x8dcM\x12\x97\xce\xdd\xf8\xf4\xc1\xa3\xbb\xa1\x03\x12]\x12%i\x1f\x1c\xf9\x90\x88r{\xbeu"
test.decrypt('AES-128-CBC-DEC',s[0],ciphertext,n[0])
end=time.time()
print(len(ciphertext))
print(len(str(s[0])))
print(end-start)
# Out:
# Algorithm
# AES-128-CBC-DEC
# Decryption Key
# b'\x8dEe\xfb\x98tMK\x827@{\x92D\x01\x98'
# Plaintext
# Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.
# Nonce
# b'\xf6bD\x1e\xa4\x1169\x94\x06\x82j#P\xd0\x0f'
# Ciphertext
# b"\x83\x19?\xee?,\xd8\xe7\xe8|\x8el\xcdy\x19oE\xa6\x010\xf7\x1f\xee\x07\x1e\xf1T\x96\x1b\xe8\x8c\x99\x82\xf9\xf7\x05\xbd\xf8)\x85\x00h/da\x1a\xf4`N\xa9$\xc3\x11V?\x05;\xa1\x04$<\x83\x04\xef\xaeU\x82^Z,\xa0\xfd\xba\xeb\x8b^\xbb\xa1\x06\x01\xdc\x1f!@\x05\xb7Zt\xe6w|0?\xf7\xba'\xfd}G\xab\x8dcM\x12\x97\xce\xdd\xf8\xf4\xc1\xa3\xbb\xa1\x03\x12]\x12%i\x1f\x1c\xf9\x90\x88r{\xbeu"
# 128
# 40
# 0.0033397674560546875

# %%
##data length == 114
##key length == 40
start=time.time()
ciphertext=b"\xbd\xc7\x9e\xac\xff\xed\xe7\x82\xf7\x11\xd9\xc3\xdfM\xa37\xd0\xc6\x00\xafG@\xd6\xb07\xda\x15\x95\xb3E\x8a6KD\x9d\xb60\xe3\x0cf\xb6 \xe0\x0f]\xc5>\xe1\xe4\xd4\x8a\xe6\x05x,SW\xeb\xcb\x17\xd5\xe5\xc1|)X\xbf\xcb\xc5;%\xac\xd7!>\x17=]J\x84\xb9o\xe9\xa4\xb94x\x83\xc5N\xa7\xb8\x85\x0e\xd4\x91\xf6'\xb4\xcf@\xae\xa3\xfc\x06\\\xb1v#\xc7\r\xfaJ\x0e"
test.decrypt('AES-128-CTR-DEC',s[0],ciphertext,n[1])
end=time.time()
print(len(ciphertext))
print(len(str(s[0])))
print(end-start)
# Out:
# Algorithm
# AES-128-CTR-DEC
# Decryption Key
# b'\x8dEe\xfb\x98tMK\x827@{\x92D\x01\x98'
# Plaintext
# Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.
# Nonce
# b'\xf2v\x89\xb5\xb1X\x9d\x03'
# Ciphertext
# b"\xbd\xc7\x9e\xac\xff\xed\xe7\x82\xf7\x11\xd9\xc3\xdfM\xa37\xd0\xc6\x00\xafG@\xd6\xb07\xda\x15\x95\xb3E\x8a6KD\x9d\xb60\xe3\x0cf\xb6 \xe0\x0f]\xc5>\xe1\xe4\xd4\x8a\xe6\x05x,SW\xeb\xcb\x17\xd5\xe5\xc1|)X\xbf\xcb\xc5;%\xac\xd7!>\x17=]J\x84\xb9o\xe9\xa4\xb94x\x83\xc5N\xa7\xb8\x85\x0e\xd4\x91\xf6'\xb4\xcf@\xae\xa3\xfc\x06\\\xb1v#\xc7\r\xfaJ\x0e"
# 114
# 40
# 0.0028319358825683594

# %%
##data length == 114
##key length == 2048 bits
start=time.time()
ciphertext=b's\x18F\xfa\xf0kb\xd8\xd2\x1c\x0b\x0e\xebY\x00x\xa1\xe7T\r\x93\xe3\xdc1\xcapnj\xae\xe1,\xfaR\x01H\xa6u\x1b-\x85y \x05B\xef\xfbm/\xc7Y\xa9\xb0\xa1^\x17\x18\xb7I\xf8\\\xca]\x88\xff\xfb\xe4\xea\x96\xc5\xf9\xa2?a\xd3\x0ePui\x08Z\xf3\x02\xe3\xb7\x19M\xa7K\x15\xe6\xf2*R5\xc4\xde\xa7@N0\xaa\xb8]~\xda#O\x02\xb5a\xf7\xd5"\xebQ~\'\xfaI\xd2\x9b\xa7\xce\xf4X\x1act\xb1E\xc1H|\xe0\xda\x81s\xe5\x9a\xe1\xdeJR\xb3\xd0D\xad\x1a\x03\x11Lu\x8f\xd2\xe1\xcb\xb8\xcc\x89\xae\xee\xcb \xdcc\xb6\xa3\xf4\xd5c\xb1\x81\xb3X\x95\xac%\xa1\xa5c\x97\xbb\x0c\xaa\xe7\xd0K,?\x1et\xec\xfb&\xee\xb4\'\xdd,\xdc\xd0\x96\x0e\xce\xcat\x95\xd8\xd5j@y\x01aO\xd4a\x85R{\xa2P\xa5\xb9z\x00\x1a\x15\xd2~h\x0c"ojBiG\xff4\xa96\x9a7\x16\xcc\x97\xc9 u\xc1`\\[\x01\x95'
test.decrypt('RSA-2048-DEC',s[4],ciphertext,n[2])
end=time.time()
print(len(ciphertext))
print(end-start)
# Out:
# Algorithm
# RSA-2048-DEC
# Decryption Key
# PrivateKey(..., 65537, ..., , )
# Plaintext
# b'Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.'
# Nonce
# b'\xf1\xf2<\xfa\xed\x0e>~\x93,\x89bs\xa4\xcf\x96Lo\xb4\xcf\x06\xf0Z\xfa\xfa\xe4\x9d\xd8]KS\xef\x1d\xf5/\x82o\xa0i\xa4|\xf77\xcb\xa9\xbc\xfaR\xeb\x9c\xde\xaa\x0c\x15h\xafX%\xd0_\xeb\xe2\xc41\xcfa\x1c\xfb*\xc1/jd4\xcf\x81\xf7\xdbu\xb7|\xd0\xf4\x89WO\xb1Z\xf9\xc5\xbcz\x15 {\x97\xa8#9\x7f\xd7L\xec\xd9\xef\x01\x8f<\\\xf0\xe8\x084\x928\xcdL\x94Gk\x91|\xc2]\x1b/]\xf3\x05r#\x94K\xe7K\xdb\xb1\xf5\xf4t)_\x95@\x8c\x88\x88X\x89\xdf5v+\xe3\xa4\xa5\xae+2\xe1\xcb\x96\xeb\xaeHn\xfd\r\x7f\xb2\x96y\xe0\x9c0\x0ch\xc9\x8aj\xde\xa5\x08F%\xce#O\xc8\xd5 d\xd3\x9e\xe1\xfcF\xbc\x9d\x04*w\xc0\xb7\xda\xdb\xfe/\xf4\x90\x95\xfb\xeb\xe2\x1b\xbd\xe4\xb5\xeb\xbb\xd5\xdbg\x10\xda\x8b\xe8\xc4\x9d\xe8\xd4\xc2\xce])\x97\xdf\xb3\xf3\t\xba\x10\xc3\x9d\xf8\xa4F\xc0fM\xc3\x0b\x8e\xe0\xecq'
# Ciphertext
# b's\x18F\xfa\xf0kb\xd8\xd2\x1c\x0b\x0e\xebY\x00x\xa1\xe7T\r\x93\xe3\xdc1\xcapnj\xae\xe1,\xfaR\x01H\xa6u\x1b-\x85y \x05B\xef\xfbm/\xc7Y\xa9\xb0\xa1^\x17\x18\xb7I\xf8\\\xca]\x88\xff\xfb\xe4\xea\x96\xc5\xf9\xa2?a\xd3\x0ePui\x08Z\xf3\x02\xe3\xb7\x19M\xa7K\x15\xe6\xf2*R5\xc4\xde\xa7@N0\xaa\xb8]~\xda#O\x02\xb5a\xf7\xd5"\xebQ~\'\xfaI\xd2\x9b\xa7\xce\xf4X\x1act\xb1E\xc1H|\xe0\xda\x81s\xe5\x9a\xe1\xdeJR\xb3\xd0D\xad\x1a\x03\x11Lu\x8f\xd2\xe1\xcb\xb8\xcc\x89\xae\xee\xcb \xdcc\xb6\xa3\xf4\xd5c\xb1\x81\xb3X\x95\xac%\xa1\xa5c\x97\xbb\x0c\xaa\xe7\xd0K,?\x1et\xec\xfb&\xee\xb4\'\xdd,\xdc\xd0\x96\x0e\xce\xcat\x95\xd8\xd5j@y\x01aO\xd4a\x85R{\xa2P\xa5\xb9z\x00\x1a\x15\xd2~h\x0c"ojBiG\xff4\xa96\x9a7\x16\xcc\x97\xc9 u\xc1`\\[\x01\x95'
# 256
# 0.04288363456726074

# %%
##data length == 114
##key length == 40
start=time.time()
plaintext="Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration."
test.generate_auth_tag('AES-128-CMAC-GEN',s[0],plaintext,n[0])
end=time.time()
print(len(plaintext))
print(len(str(s[0])))
print(end-start)
# Out:
# Algorithm
# AES-128-CMAC-GEN
# Authentication Key
# b'\x8dEe\xfb\x98tMK\x827@{\x92D\x01\x98'
# Plaintext
# Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.
# Nonce
# b'\xf6bD\x1e\xa4\x1169\x94\x06\x82j#P\xd0\x0f'
# Authentication Tag
# b'lW\x8d\xca:\x9a-]/\xac\xfa2\x1em\xf3X'
# 114
# 40
# 0.004812955856323242

# %%
##data length == 114
##key length == 40
start=time.time()
plaintext="Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration."
test.generate_auth_tag('SHA3-256-HMAC-GEN',s[0],plaintext,n[4])
end=time.time()
print(len(plaintext))
print(len(str(s[0])))
print(end-start)
# Out:
# Algorithm
# SHA3-256-HMAC-GEN
# Authentication Key
# b'\x8dEe\xfb\x98tMK\x827@{\x92D\x01\x98'
# Plaintext
# Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.
# Nonce
# b'\x85\x80\x02\x83N\xfa\xb4`FvF7\xb9\xb2\x18\x94\xbb}\xa8L\x9d=\x85v\x9f\x0b^\x8d\xe4\xb9Q\xbf'
# Authentication Tag
# b'\xa4\x1f\x0em\x05\xee\xe8Nv\x81O\x18\xf7\xb6\xbbQ\xab\xad$&\xba\x19\xa2\xc6\x0b}\xf4\x15i\xaf\x17\xb2'
# 114
# 40
# 0.003381967544555664

# %%
##data length == 114
##key length == 2048 bits
start=time.time()
plaintext="Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration."
test.generate_auth_tag('RSA-2048-SHA3-256-SIG-GEN',s[2],plaintext,n[5])
end=time.time()
print(len(plaintext))
print(end-start)
# Out:
# Algorithm
# RSA-2048-SHA3-256-SIG-GEN
# Authentication Key
# PrivateKey(..., 65537, ..., , )
# Plaintext
# Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.
# Nonce
# b'\x10\xe1\n\xbd2\x07\x10o\xa7\x94\xd4\xd8\xa6\xfb\x81wJ\xd2\xfeyI\x95\xf0\xec\xb4^\x8f+\xbd5\x04\xc9'
# Authentication Tag
# b'Oh\x0c6ku\xf0O\xady\xe4\xee\xda\xbc-E\xc4\x97\xbd\x00mY\x19\xe8`B\xaf\x0b:l\xbf\xcb\xdcC\xe6\x0e\xd1\xc1\xee\xd8y\xdb~\xb3\x98F\x1a\tJ\x9b\xce\xe6\xfe"e$\x9a\xd0|Y\xbe\xf3\xd0\x1e\xce\xeb\xf8\x1emD\xbe.\x99\xdf\xcf\x96\xa1H0xE\xb3\xf2\xfc@x\x1d\xdb\xdf\xb4\xbf8\\\x84\xf5\r\xf5\xf4\x97\x1a\xa6\xc6\x19\n~Y\r2\xa0\xbbj_\xc7\x14\x88~|\xd6_\xa6\xc5A\xbaa=\x82\x9a\xb8\xb5X\x1d+\xc3\x84%;QF\x1b\xae\xb7`\xe0\xbf5\x13\xa4\x9fs\xad\xdbx\xf2\xa5)\x15\xdb\xe4^D\xc1\x1c\rD\x16\xfeGV\xfe\x18\x91\xe9\xc3GW\x9a}\x89c\xa8\xa8m\xfb\xf1%\xcc/\xd2G<\xfd\xae\xd7\xe0+j\xfb{\x91\xebqU\x0c\xc7\xb2#~]\xb6\x9f\xd1\xec^W\xa0\x18Q\xbb%\x12L\xefE\x1d\x87\xca\xac\xb4\xb0\xc4]\xae\xadhl\x13\xaan"\x01z\x00\xddA\x17\xc3\x1ed\x83\xd9^7\xaeoK\xa3'
# 114
# 0.033080101013183594

# %%
##data length == 114
##key length == 2048 bits
start=time.time()
plaintext="Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration."
test.generate_auth_tag('ECDSA-256-SHA3-256-SIG-GEN',s[6],plaintext,n[6])
end=time.time()
print(len(plaintext))
print(end-start)
# Out:
# Algorithm
# ECDSA-256-SHA3-256-SIG-GEN
# Authentication Key
# <cryptography.hazmat.backends.openssl.ec._EllipticCurvePrivateKey object at 0x7f850253ddc0>
# Plaintext
# Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.
# Nonce
# b'\xdad\xdd\xbc\xa8\x9a\x86\xeeU\xd5\xaaH\x8bg\x9e-\xe0.\x12\xfcv\xfe\xae\xc1O\xef\x0e;}\xc8U\xb4'
# Authentication Tag
# b"0E\x02 8S9C\x07$\xa0`aogx\x8a\xd5\xb4\x86V{\x0bL-\x0c\x838\xcfR\x9c\x1c\x12\xbe\xbe%\x02!\x00\xaam\t\x16\x9d\x1fL\xdd'[\x08\xd3Tq\x93\xdd\xbc&\x1f\x13J\xb7\xa9\x08/\xe5\x01\xceD\xe8{c"
# 114
# 0.010205984115600586

# %%
##data length == 114
##key length == 2048 bits
start=time.time()
tag=b'lW\x8d\xca:\x9a-]/\xac\xfa2\x1em\xf3X'
plaintext="Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration."
test.verify_auth_tag('AES-128-CMAC-VRF',s[0],plaintext,n[0],tag)
end=time.time()
print(len(plaintext))
print(end-start)
# Out:
# Algorithm
# AES-128-CMAC-VRF
# Authentication Key
# b'\x8dEe\xfb\x98tMK\x827@{\x92D\x01\x98'
# Plaintext
# Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.
# Nonce
# b'\xf6bD\x1e\xa4\x1169\x94\x06\x82j#P\xd0\x0f'
# Authentication Tag
# b'lW\x8d\xca:\x9a-]/\xac\xfa2\x1em\xf3X'
# Authentication Tag Valid
# True
# 114
# 0.002977132797241211

# %%
##key length == 2048 bits
start=time.time()
tag=b'\xa4\x1f\x0em\x05\xee\xe8Nv\x81O\x18\xf7\xb6\xbbQ\xab\xad$&\xba\x19\xa2\xc6\x0b}\xf4\x15i\xaf\x17\xb2'
plaintext="Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration."
test.verify_auth_tag('SHA3-256-HMAC-VRF',s[0],plaintext,n[0],tag)
end=time.time()
print(len(plaintext))
print(end-start)
# Out:
# Algorithm
# SHA3-256-HMAC-VRF
# Authentication Key
# b'\x8dEe\xfb\x98tMK\x827@{\x92D\x01\x98'
# Plaintext
# Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.
# Nonce
# b'\xf6bD\x1e\xa4\x1169\x94\x06\x82j#P\xd0\x0f'
# Authentication Tag
# b'\xa4\x1f\x0em\x05\xee\xe8Nv\x81O\x18\xf7\xb6\xbbQ\xab\xad$&\xba\x19\xa2\xc6\x0b}\xf4\x15i\xaf\x17\xb2'
# Authentication Tag Valid
# True
# 114
# 0.002747774124145508

# %%
##key length == 2048 bits
start=time.time()
tag=b'Oh\x0c6ku\xf0O\xady\xe4\xee\xda\xbc-E\xc4\x97\xbd\x00mY\x19\xe8`B\xaf\x0b:l\xbf\xcb\xdcC\xe6\x0e\xd1\xc1\xee\xd8y\xdb~\xb3\x98F\x1a\tJ\x9b\xce\xe6\xfe"e$\x9a\xd0|Y\xbe\xf3\xd0\x1e\xce\xeb\xf8\x1emD\xbe.\x99\xdf\xcf\x96\xa1H0xE\xb3\xf2\xfc@x\x1d\xdb\xdf\xb4\xbf8\\\x84\xf5\r\xf5\xf4\x97\x1a\xa6\xc6\x19\n~Y\r2\xa0\xbbj_\xc7\x14\x88~|\xd6_\xa6\xc5A\xbaa=\x82\x9a\xb8\xb5X\x1d+\xc3\x84%;QF\x1b\xae\xb7`\xe0\xbf5\x13\xa4\x9fs\xad\xdbx\xf2\xa5)\x15\xdb\xe4^D\xc1\x1c\rD\x16\xfeGV\xfe\x18\x91\xe9\xc3GW\x9a}\x89c\xa8\xa8m\xfb\xf1%\xcc/\xd2G<\xfd\xae\xd7\xe0+j\xfb{\x91\xebqU\x0c\xc7\xb2#~]\xb6\x9f\xd1\xec^W\xa0\x18Q\xbb%\x12L\xefE\x1d\x87\xca\xac\xb4\xb0\xc4]\xae\xadhl\x13\xaan"\x01z\x00\xddA\x17\xc3\x1ed\x83\xd9^7\xaeoK\xa3'
plaintext="Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration."
test.verify_auth_tag('RSA-2048-SHA3-256-SIG-VRF',s[1],plaintext,n[5],tag)
end=time.time()
print(len(plaintext))
print(end-start)
# Out:
# Algorithm
# RSA-2048-SHA3-256-SIG-VRF
# Authentication Key
# PublicKey(..., 65537)
# Plaintext
# Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.
# Nonce
# b'\x10\xe1\n\xbd2\x07\x10o\xa7\x94\xd4\xd8\xa6\xfb\x81wJ\xd2\xfeyI\x95\xf0\xec\xb4^\x8f+\xbd5\x04\xc9'
# Authentication Tag
# b'Oh\x0c6ku\xf0O\xady\xe4\xee\xda\xbc-E\xc4\x97\xbd\x00mY\x19\xe8`B\xaf\x0b:l\xbf\xcb\xdcC\xe6\x0e\xd1\xc1\xee\xd8y\xdb~\xb3\x98F\x1a\tJ\x9b\xce\xe6\xfe"e$\x9a\xd0|Y\xbe\xf3\xd0\x1e\xce\xeb\xf8\x1emD\xbe.\x99\xdf\xcf\x96\xa1H0xE\xb3\xf2\xfc@x\x1d\xdb\xdf\xb4\xbf8\\\x84\xf5\r\xf5\xf4\x97\x1a\xa6\xc6\x19\n~Y\r2\xa0\xbbj_\xc7\x14\x88~|\xd6_\xa6\xc5A\xbaa=\x82\x9a\xb8\xb5X\x1d+\xc3\x84%;QF\x1b\xae\xb7`\xe0\xbf5\x13\xa4\x9fs\xad\xdbx\xf2\xa5)\x15\xdb\xe4^D\xc1\x1c\rD\x16\xfeGV\xfe\x18\x91\xe9\xc3GW\x9a}\x89c\xa8\xa8m\xfb\xf1%\xcc/\xd2G<\xfd\xae\xd7\xe0+j\xfb{\x91\xebqU\x0c\xc7\xb2#~]\xb6\x9f\xd1\xec^W\xa0\x18Q\xbb%\x12L\xefE\x1d\x87\xca\xac\xb4\xb0\xc4]\xae\xadhl\x13\xaan"\x01z\x00\xddA\x17\xc3\x1ed\x83\xd9^7\xaeoK\xa3'
# Authentication Tag Valid
# True
# 114
# 0.0020151138305664062

# %%
start=time.time()
tag=b"0E\x02 8S9C\x07$\xa0`aogx\x8a\xd5\xb4\x86V{\x0bL-\x0c\x838\xcfR\x9c\x1c\x12\xbe\xbe%\x02!\x00\xaam\t\x16\x9d\x1fL\xdd'[\x08\xd3Tq\x93\xdd\xbc&\x1f\x13J\xb7\xa9\x08/\xe5\x01\xceD\xe8{c"
plaintext="Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration."
test.verify_auth_tag('ECDSA-256-SHA3-256-SIG-VRF',s[5],plaintext,n[5],tag)
end=time.time()
print(len(plaintext))
print(end-start)
# Out:
# Algorithm
# ECDSA-256-SHA3-256-SIG-VRF
# Authentication Key
# <cryptography.hazmat.backends.openssl.ec._EllipticCurvePublicKey object at 0x7f850269e790>
# Plaintext
# Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.
# Nonce
# b'\x10\xe1\n\xbd2\x07\x10o\xa7\x94\xd4\xd8\xa6\xfb\x81wJ\xd2\xfeyI\x95\xf0\xec\xb4^\x8f+\xbd5\x04\xc9'
# Authentication Tag
# b"0E\x02 8S9C\x07$\xa0`aogx\x8a\xd5\xb4\x86V{\x0bL-\x0c\x838\xcfR\x9c\x1c\x12\xbe\xbe%\x02!\x00\xaam\t\x16\x9d\x1fL\xdd'[\x08\xd3Tq\x93\xdd\xbc&\x1f\x13J\xb7\xa9\x08/\xe5\x01\xceD\xe8{c"
# Authentication Tag Valid
# True
# 114
# 0.007790088653564453

# %%
##data length == 114
##key length == 40
start=time.time()
plaintext="Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration."
test.encrypt_generate_auth('AES-128-GCM-GEN',s[0],s[0],plaintext,n[0])
end=time.time()
print(len(plaintext))
print(len(str(s[0])))
print(end-start)
# Out:
# Algorithm
# AES-128-GCM-GEN
# Encryption Key
# b'\x8dEe\xfb\x98tMK\x827@{\x92D\x01\x98'
# Authentication Key
# b'\x8dEe\xfb\x98tMK\x827@{\x92D\x01\x98'
# Plaintext
# Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.
# Nonce
# b'\xf6bD\x1e\xa4\x1169\x94\x06\x82j#P\xd0\x0f'
# Ciphertext
# b'\x17\xa2*T\xfbU\xfe\xf5\xde\x98q\xd5\xa5\x9308[P\xc0&\xa4g\xe1\xa3\x94\xa9\xf9?\x97\x83\xb1\xdf\xac\x9fQc\x12_\xc7\x12\x0bL\x8b\xad\xc0\x9b\x86\xf3\x88\x11\x1fX\x99\xfd\xcc\x9c\xce-\x01R\x9ew\x7f\xdbO\xc1z\xeb\xfaU\xc0\xa4\xce\xa42\xbe\xb4};-\xbb\xcb\x1d\x07\x93\xdc\xe5\xbe\xe3\xf6Q\xcf\x1e!X_\xac\xcf`\xab)#C\xe1P\xecK\xe3\xef\x01\x870\xeb\x1f'
# Authentication Tag
# b'D`0\x8b\x02\x90\xff Q\xb5\xce\x8d\xcbiN/'
# 114
# 40
# 0.007241010665893555

# %%
##data length == 114
##key length == 40
start=time.time()
ciphertext=b'\x17\xa2*T\xfbU\xfe\xf5\xde\x98q\xd5\xa5\x9308[P\xc0&\xa4g\xe1\xa3\x94\xa9\xf9?\x97\x83\xb1\xdf\xac\x9fQc\x12_\xc7\x12\x0bL\x8b\xad\xc0\x9b\x86\xf3\x88\x11\x1fX\x99\xfd\xcc\x9c\xce-\x01R\x9ew\x7f\xdbO\xc1z\xeb\xfaU\xc0\xa4\xce\xa42\xbe\xb4};-\xbb\xcb\x1d\x07\x93\xdc\xe5\xbe\xe3\xf6Q\xcf\x1e!X_\xac\xcf`\xab)#C\xe1P\xecK\xe3\xef\x01\x870\xeb\x1f'
plaintext="Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration."
tag=b'D`0\x8b\x02\x90\xff Q\xb5\xce\x8d\xcbiN/'
test.decrypt_verify_auth('AES-128-GCM-VRF',s[0],s[0],ciphertext,bytes(n[0]),tag)
end=time.time()
print(len(plaintext))
print(len(str(s[0])))
print(end-start)
# Out:
# Algorithm
# AES-128-GCM-VRF
# Decryption Key
# b'\x8dEe\xfb\x98tMK\x827@{\x92D\x01\x98'
# Authentication Key
# b'\x8dEe\xfb\x98tMK\x827@{\x92D\x01\x98'
# Plaintext
# Paris 2024 will see a new vision of Olympism in action, delivered in a unique spirit of international celebration.
# Nonce
# b'\xf6bD\x1e\xa4\x1169\x94\x06\x82j#P\xd0\x0f'
# Ciphertext
# b'\x17\xa2*T\xfbU\xfe\xf5\xde\x98q\xd5\xa5\x9308[P\xc0&\xa4g\xe1\xa3\x94\xa9\xf9?\x97\x83\xb1\xdf\xac\x9fQc\x12_\xc7\x12\x0bL\x8b\xad\xc0\x9b\x86\xf3\x88\x11\x1fX\x99\xfd\xcc\x9c\xce-\x01R\x9ew\x7f\xdbO\xc1z\xeb\xfaU\xc0\xa4\xce\xa42\xbe\xb4};-\xbb\xcb\x1d\x07\x93\xdc\xe5\xbe\xe3\xf6Q\xcf\x1e!X_\xac\xcf`\xab)#C\xe1P\xecK\xe3\xef\x01\x870\xeb\x1f'
# Authentication Tag
# b'D`0\x8b\x02\x90\xff Q\xb5\xce\x8d\xcbiN/'
# Authentication Tag Valid
# True
# 114
# 40
# 0.008770942687988281
